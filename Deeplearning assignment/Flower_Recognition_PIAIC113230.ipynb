# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.optimizers import RMSprop

# %%
import glob
import cv2
import numpy as np

with tf.device('/device:GPU:0'):

  IMG_DIR='/content/drive/MyDrive/PIAIC/flower-recognition/daisy'
  IMG_DIR1='/content/drive/MyDrive/PIAIC/flower-recognition/dandelion'
  IMG_DIR2='/content/drive/MyDrive/PIAIC/flower-recognition/rose'
  IMG_DIR3='/content/drive/MyDrive/PIAIC/flower-recognition/sunflower'
  IMG_DIR4='/content/drive/MyDrive/PIAIC/flower-recognition/tulip'

  def read_images(directory):
      for img in glob.glob(directory+"/*.jpg"):
          image = cv2.imread(img)
          resized_img = cv2.resize(image/255.0  , (150 , 150))

          yield resized_img

  resized_imgs0 =  np.array(list(read_images(IMG_DIR)))
  resized_imgs1 =  np.array(list(read_images(IMG_DIR1)))
  resized_imgs2 =  np.array(list(read_images(IMG_DIR2)))
  resized_imgs3 =  np.array(list(read_images(IMG_DIR3)))
  resized_imgs4 =  np.array(list(read_images(IMG_DIR4)))

# %%
label0 = np.zeros((resized_imgs0.shape[0],1))   #0
label1 = np.ones((resized_imgs1.shape[0],1))  #1
label2 = np.ones((resized_imgs2.shape[0],1))*2 #2
label3 = np.ones((resized_imgs3.shape[0],1))*3 #3
label4 = np.ones((resized_imgs4.shape[0],1))*4  #4

# %%
data = np.concatenate((resized_imgs0,resized_imgs1,resized_imgs2,resized_imgs3,resized_imgs4))

# %%
data= data.reshape(data.shape[0], data.shape[1]*data.shape[2]*data.shape[3])

# %%
labels = np.concatenate((label0,label1,label2,label3,label4))

# %%
del resized_imgs0
del resized_imgs1
del resized_imgs2
del resized_imgs3
del resized_imgs4
del label0
del label1
del label2
del label3
del label4

# %%
import pandas as pd
data = pd.DataFrame(data)
data['labels'] = labels.astype('float32')

# %%
from sklearn.model_selection import train_test_split
train_data, test_data, train_labels, test_labels=train_test_split(data.iloc[0:,:-1], data['labels'], test_size=0.3, random_state=42, stratify = labels)

# %%
train_data = np.array(train_data).reshape(len(train_data),150,150,3)

# %%
test_data = np.array(test_data).reshape(len(test_data),150,150,3)

# %%
train_labels = np.array(train_labels).astype('float32')
test_labels = np.array(test_labels).astype('float32')

# %%
data_gen = tf.keras.preprocessing.image.ImageDataGenerator(

    zca_epsilon=1e-06,
    rotation_range=0,
    width_shift_range=0.0,
    height_shift_range=0.0,
    brightness_range=None,
    shear_range=0.3,
    zoom_range=0.2,
    channel_shift_range=0.3,
    fill_mode="nearest",
    cval=0.0,
    horizontal_flip=True,
    vertical_flip=False,
    rescale=None,
    preprocessing_function=None,
    data_format=None,
    validation_split=0.0,
    dtype=None,
)

# %%
data_gen.fit(train_data)

# %%
data_gen.fit(test_data)

# %%
#MOdels with COnv2D and Maxpooling
model = tf.keras.models.Sequential([
    # Note the input shape is the desired size of the image 150x150 with 3 bytes color
    # This is the first convolution
    tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(150, 150, 3,)),
    tf.keras.layers.MaxPooling2D(2, 2),
    # The second convolution
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # The third convolution
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # The fourth convolution
    tf.keras.layers.Conv2D(16, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # Flatten the results to feed into a DNN
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dropout(0.5),
    # 512 neuron hidden layer
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(5, activation='softmax')
])

# %%
model.compile(optimizer=RMSprop(learning_rate= 0.0001),
loss='sparse_categorical_crossentropy',
metrics=['accuracy'])

# %%
# %tensorflow_version 2.x
import tensorflow as tf

# %%
with tf.device('/device:GPU:0'):
  result = model.fit(
          x= train_data,
          y= train_labels,
          batch_size = 30,
          steps_per_epoch=30,
          epochs=100,
          validation_split=0.3,
          validation_steps=10,
          validation_batch_size=10)
# Out:
# Epoch 1/100
# 30/30 [==============================] - 47s 2s/step - loss: 1.6087 - accuracy: 0.2256 - val_loss: 1.5597 - val_accuracy: 0.3400
# Epoch 2/100
# 30/30 [==============================] - 46s 2s/step - loss: 1.5411 - accuracy: 0.3240 - val_loss: 1.4487 - val_accuracy: 0.3700
# Epoch 3/100
# 30/30 [==============================] - 45s 1s/step - loss: 1.4226 - accuracy: 0.4202 - val_loss: 1.3474 - val_accuracy: 0.3600
# Epoch 4/100
# 30/30 [==============================] - 46s 2s/step - loss: 1.3314 - accuracy: 0.4122 - val_loss: 1.3089 - val_accuracy: 0.3800
# Epoch 5/100
# 30/30 [==============================] - 45s 1s/step - loss: 1.2481 - accuracy: 0.4257 - val_loss: 1.2797 - val_accuracy: 0.3800
# Epoch 6/100
# 30/30 [==============================] - 46s 2s/step - loss: 1.2410 - accuracy: 0.4422 - val_loss: 1.2633 - val_accuracy: 0.3600
# Epoch 7/100
# 30/30 [==============================] - 46s 2s/step - loss: 1.2382 - accuracy: 0.4594 - val_loss: 1.2419 - val_accuracy: 0.4400
# Epoch 8/100
# 30/30 [==============================] - 44s 1s/step - loss: 1.2277 - accuracy: 0.4252 - val_loss: 1.2383 - val_accuracy: 0.4800
# Epoch 9/100
# 30/30 [==============================] - 46s 2s/step - loss: 1.2061 - accuracy: 0.4414 - val_loss: 1.1914 - val_accuracy: 0.5100
# Epoch 10/100
# 30/30 [==============================] - 45s 2s/step - loss: 1.1442 - accuracy: 0.5269 - val_loss: 1.1932 - val_accuracy: 0.4900
# Epoch 11/100
# 30/30 [==============================] - 46s 2s/step - loss: 1.1523 - accuracy: 0.5170 - val_loss: 1.1855 - val_accuracy: 0.5400
# Epoch 12/100
# 30/30 [==============================] - 45s 1s/step - loss: 1.1934 - accuracy: 0.4869 - val_loss: 1.1724 - val_accuracy: 0.5200
# Epoch 13/100
# 30/30 [==============================] - 46s 2s/step - loss: 1.1920 - accuracy: 0.5160 - val_loss: 1.1474 - val_accuracy: 0.5200
# Epoch 14/100
# 30/30 [==============================] - 47s 2s/step - loss: 1.1601 - accuracy: 0.5291 - val_loss: 1.1222 - val_accuracy: 0.5600
# Epoch 15/100
# 30/30 [==============================] - 45s 2s/step - loss: 1.1336 - accuracy: 0.4919 - val_loss: 1.1734 - val_accuracy: 0.4900
# Epoch 16/100
# 30/30 [==============================] - 46s 2s/step - loss: 1.0743 - accuracy: 0.5488 - val_loss: 1.1755 - val_accuracy: 0.5300
# Epoch 17/100
# 30/30 [==============================] - 45s 2s/step - loss: 1.1092 - accuracy: 0.5543 - val_loss: 1.1334 - val_accuracy: 0.5400
# Epoch 18/100
# 30/30 [==============================] - 46s 2s/step - loss: 1.0397 - accuracy: 0.5689 - val_loss: 1.0705 - val_accuracy: 0.6000
# Epoch 19/100
# 30/30 [==============================] - 46s 2s/step - loss: 1.0415 - accuracy: 0.5822 - val_loss: 1.0861 - val_accuracy: 0.6200
# Epoch 20/100
# 30/30 [==============================] - 45s 1s/step - loss: 1.0977 - accuracy: 0.5765 - val_loss: 1.0913 - val_accuracy: 0.6100
# Epoch 21/100
# 30/30 [==============================] - 46s 2s/step - loss: 1.0661 - accuracy: 0.5717 - val_loss: 1.1450 - val_accuracy: 0.5300
# Epoch 22/100
# 30/30 [==============================] - 44s 1s/step - loss: 1.0947 - accuracy: 0.5526 - val_loss: 1.0653 - val_accuracy: 0.5800
# Epoch 23/100
# 30/30 [==============================] - 46s 2s/step - loss: 1.0414 - accuracy: 0.5735 - val_loss: 1.0790 - val_accuracy: 0.5900
# Epoch 24/100
# 30/30 [==============================] - 45s 1s/step - loss: 1.0376 - accuracy: 0.6020 - val_loss: 1.0772 - val_accuracy: 0.5400
# Epoch 25/100
# 30/30 [==============================] - 46s 2s/step - loss: 1.0867 - accuracy: 0.5471 - val_loss: 1.0557 - val_accuracy: 0.5700
# Epoch 26/100
# 30/30 [==============================] - 46s 2s/step - loss: 0.9830 - accuracy: 0.6226 - val_loss: 1.0542 - val_accuracy: 0.6300
# Epoch 27/100
# 30/30 [==============================] - 45s 1s/step - loss: 0.9732 - accuracy: 0.6506 - val_loss: 1.0146 - val_accuracy: 0.6600
# Epoch 28/100
# 30/30 [==============================] - 46s 2s/step - loss: 0.9909 - accuracy: 0.5973 - val_loss: 1.0152 - val_accuracy: 0.6400
# Epoch 29/100
# 30/30 [==============================] - 45s 1s/step - loss: 0.9496 - accuracy: 0.6325 - val_loss: 1.0376 - val_accuracy: 0.6100
# Epoch 30/100
# 30/30 [==============================] - 45s 2s/step - loss: 1.0130 - accuracy: 0.6030 - val_loss: 1.0168 - val_accuracy: 0.6400
# Epoch 31/100
# 30/30 [==============================] - 45s 2s/step - loss: 0.9505 - accuracy: 0.6395 - val_loss: 1.0009 - val_accuracy: 0.6300
# Epoch 32/100
# 30/30 [==============================] - 44s 1s/step - loss: 0.9899 - accuracy: 0.6379 - val_loss: 0.9936 - val_accuracy: 0.5800
# Epoch 33/100
# 30/30 [==============================] - 45s 2s/step - loss: 0.9500 - accuracy: 0.6120 - val_loss: 0.9845 - val_accuracy: 0.6600
# Epoch 34/100
# 30/30 [==============================] - 44s 1s/step - loss: 0.9105 - accuracy: 0.6334 - val_loss: 0.9774 - val_accuracy: 0.6200
# Epoch 35/100
# 30/30 [==============================] - 45s 2s/step - loss: 0.9774 - accuracy: 0.5971 - val_loss: 1.0243 - val_accuracy: 0.6300
# Epoch 36/100
# 30/30 [==============================] - 44s 1s/step - loss: 0.9681 - accuracy: 0.6222 - val_loss: 1.1211 - val_accuracy: 0.5600
# Epoch 37/100
# 30/30 [==============================] - 45s 2s/step - loss: 0.9151 - accuracy: 0.6416 - val_loss: 0.9553 - val_accuracy: 0.6700
# Epoch 38/100
# 30/30 [==============================] - 45s 2s/step - loss: 0.9528 - accuracy: 0.6153 - val_loss: 1.0164 - val_accuracy: 0.6100
# Epoch 39/100
# 30/30 [==============================] - 44s 1s/step - loss: 0.9683 - accuracy: 0.6288 - val_loss: 0.9617 - val_accuracy: 0.6500
# Epoch 40/100
# 30/30 [==============================] - 46s 2s/step - loss: 0.9511 - accuracy: 0.6177 - val_loss: 1.0120 - val_accuracy: 0.6200
# Epoch 41/100
# 30/30 [==============================] - 45s 1s/step - loss: 0.9450 - accuracy: 0.6288 - val_loss: 0.9323 - val_accuracy: 0.6600
# Epoch 42/100
# 30/30 [==============================] - 45s 2s/step - loss: 0.9063 - accuracy: 0.6433 - val_loss: 0.9367 - val_accuracy: 0.6900
# Epoch 43/100
# 30/30 [==============================] - 46s 2s/step - loss: 0.9339 - accuracy: 0.6419 - val_loss: 0.9275 - val_accuracy: 0.6900
# Epoch 44/100
# 30/30 [==============================] - 44s 1s/step - loss: 0.8758 - accuracy: 0.6570 - val_loss: 1.0241 - val_accuracy: 0.6100
# Epoch 45/100
# 30/30 [==============================] - 45s 2s/step - loss: 0.9405 - accuracy: 0.6193 - val_loss: 0.9236 - val_accuracy: 0.6500
# Epoch 46/100
# 30/30 [==============================] - 44s 1s/step - loss: 0.8680 - accuracy: 0.6752 - val_loss: 0.9538 - val_accuracy: 0.6400
# Epoch 47/100
# 30/30 [==============================] - 45s 2s/step - loss: 0.9334 - accuracy: 0.6218 - val_loss: 0.9285 - val_accuracy: 0.6900
# Epoch 48/100
# 30/30 [==============================] - 45s 1s/step - loss: 0.8288 - accuracy: 0.6664 - val_loss: 1.0565 - val_accuracy: 0.5800
# Epoch 49/100
# 30/30 [==============================] - 45s 2s/step - loss: 0.9099 - accuracy: 0.6448 - val_loss: 0.8942 - val_accuracy: 0.6800
# Epoch 50/100
# 30/30 [==============================] - 46s 2s/step - loss: 0.8861 - accuracy: 0.6544 - val_loss: 0.9277 - val_accuracy: 0.6700
# Epoch 51/100
# 30/30 [==============================] - 44s 1s/step - loss: 0.8650 - accuracy: 0.6403 - val_loss: 0.9473 - val_accuracy: 0.6300
# Epoch 52/100
# 30/30 [==============================] - 45s 2s/step - loss: 0.8652 - accuracy: 0.6570 - val_loss: 0.9317 - val_accuracy: 0.6400
# Epoch 53/100
# 30/30 [==============================] - 44s 1s/step - loss: 0.8644 - accuracy: 0.6454 - val_loss: 0.9283 - val_accuracy: 0.6400
# Epoch 54/100
# 30/30 [==============================] - 45s 2s/step - loss: 0.8674 - accuracy: 0.6760 - val_loss: 0.9024 - val_accuracy: 0.7000
# Epoch 55/100
# 30/30 [==============================] - 46s 2s/step - loss: 0.8695 - accuracy: 0.6480 - val_loss: 0.9016 - val_accuracy: 0.7100
# Epoch 56/100
# 30/30 [==============================] - 44s 1s/step - loss: 0.8840 - accuracy: 0.6628 - val_loss: 0.9076 - val_accuracy: 0.7100
# Epoch 57/100
# 30/30 [==============================] - 45s 2s/step - loss: 0.7959 - accuracy: 0.6986 - val_loss: 0.8832 - val_accuracy: 0.6900
# Epoch 58/100
# 30/30 [==============================] - 44s 1s/step - loss: 0.8309 - accuracy: 0.6498 - val_loss: 0.9143 - val_accuracy: 0.6500
# Epoch 59/100
# 30/30 [==============================] - 45s 2s/step - loss: 0.8740 - accuracy: 0.6530 - val_loss: 0.8907 - val_accuracy: 0.7100
# Epoch 60/100
# 30/30 [==============================] - 44s 1s/step - loss: 0.8408 - accuracy: 0.6576 - val_loss: 0.9153 - val_accuracy: 0.7000
# Epoch 61/100
# 30/30 [==============================] - 45s 2s/step - loss: 0.8190 - accuracy: 0.6559 - val_loss: 0.9319 - val_accuracy: 0.6800
# Epoch 62/100
# 30/30 [==============================] - 45s 2s/step - loss: 0.8024 - accuracy: 0.6625 - val_loss: 0.8992 - val_accuracy: 0.6900
# Epoch 63/100
# 30/30 [==============================] - 44s 1s/step - loss: 0.8481 - accuracy: 0.6763 - val_loss: 0.9267 - val_accuracy: 0.6200
# Epoch 64/100
# 30/30 [==============================] - 45s 2s/step - loss: 0.8352 - accuracy: 0.6906 - val_loss: 0.8777 - val_accuracy: 0.7100
# Epoch 65/100
# 30/30 [==============================] - 44s 1s/step - loss: 0.8314 - accuracy: 0.6592 - val_loss: 0.9532 - val_accuracy: 0.6000
# Epoch 66/100
# 30/30 [==============================] - 45s 2s/step - loss: 0.8169 - accuracy: 0.6882 - val_loss: 0.8681 - val_accuracy: 0.7200
# Epoch 67/100
# 30/30 [==============================] - 45s 2s/step - loss: 0.7976 - accuracy: 0.6749 - val_loss: 0.8985 - val_accuracy: 0.6600
# Epoch 68/100
# 30/30 [==============================] - 44s 1s/step - loss: 0.8463 - accuracy: 0.6607 - val_loss: 0.9096 - val_accuracy: 0.6700
# Epoch 69/100
# 30/30 [==============================] - 46s 2s/step - loss: 0.7831 - accuracy: 0.7000 - val_loss: 0.9377 - val_accuracy: 0.6500
# Epoch 70/100
# 30/30 [==============================] - 44s 1s/step - loss: 0.8131 - accuracy: 0.6858 - val_loss: 0.8546 - val_accuracy: 0.7400
# Epoch 71/100
# 30/30 [==============================] - 45s 2s/step - loss: 0.7805 - accuracy: 0.7165 - val_loss: 0.9047 - val_accuracy: 0.6700
# Epoch 72/100
# 30/30 [==============================] - 44s 1s/step - loss: 0.7654 - accuracy: 0.7020 - val_loss: 0.9379 - val_accuracy: 0.6400
# Epoch 73/100
# 30/30 [==============================] - 45s 2s/step - loss: 0.7900 - accuracy: 0.6738 - val_loss: 0.9364 - val_accuracy: 0.6100
# Epoch 74/100
# 30/30 [==============================] - 45s 2s/step - loss: 0.8173 - accuracy: 0.6831 - val_loss: 0.9430 - val_accuracy: 0.6300
# Epoch 75/100
# 30/30 [==============================] - 44s 1s/step - loss: 0.8160 - accuracy: 0.6882 - val_loss: 0.8724 - val_accuracy: 0.6800
# Epoch 76/100
# 30/30 [==============================] - 45s 2s/step - loss: 0.7815 - accuracy: 0.6843 - val_loss: 0.8519 - val_accuracy: 0.7300
# Epoch 77/100
# 30/30 [==============================] - 44s 1s/step - loss: 0.8017 - accuracy: 0.6946 - val_loss: 0.8532 - val_accuracy: 0.7100
# Epoch 78/100
# 30/30 [==============================] - 45s 1s/step - loss: 0.8047 - accuracy: 0.6990 - val_loss: 0.8425 - val_accuracy: 0.7200
# Epoch 79/100
# 30/30 [==============================] - 45s 1s/step - loss: 0.7793 - accuracy: 0.7035 - val_loss: 0.8699 - val_accuracy: 0.7100
# Epoch 80/100
# 30/30 [==============================] - 44s 1s/step - loss: 0.7878 - accuracy: 0.6896 - val_loss: 0.8662 - val_accuracy: 0.6600
# Epoch 81/100
# 30/30 [==============================] - 45s 1s/step - loss: 0.7413 - accuracy: 0.6969 - val_loss: 0.8529 - val_accuracy: 0.7100
# Epoch 82/100
# 30/30 [==============================] - 44s 1s/step - loss: 0.7955 - accuracy: 0.6637 - val_loss: 0.8614 - val_accuracy: 0.7000
# Epoch 83/100
# 30/30 [==============================] - 45s 2s/step - loss: 0.7460 - accuracy: 0.6914 - val_loss: 0.8235 - val_accuracy: 0.7300
# Epoch 84/100
# 30/30 [==============================] - 44s 1s/step - loss: 0.7340 - accuracy: 0.7060 - val_loss: 1.0017 - val_accuracy: 0.6300
# Epoch 85/100
# 30/30 [==============================] - 45s 1s/step - loss: 0.7272 - accuracy: 0.7195 - val_loss: 0.8645 - val_accuracy: 0.6900
# Epoch 86/100
# 30/30 [==============================] - 45s 2s/step - loss: 0.8124 - accuracy: 0.6826 - val_loss: 0.8699 - val_accuracy: 0.6400
# Epoch 87/100
# 30/30 [==============================] - 45s 1s/step - loss: 0.7467 - accuracy: 0.7437 - val_loss: 0.8298 - val_accuracy: 0.7300
# Epoch 88/100
# 30/30 [==============================] - 46s 2s/step - loss: 0.7169 - accuracy: 0.7256 - val_loss: 1.0152 - val_accuracy: 0.6300
# Epoch 89/100
# 30/30 [==============================] - 44s 1s/step - loss: 0.8310 - accuracy: 0.6632 - val_loss: 0.8460 - val_accuracy: 0.6700
# Epoch 90/100
# 30/30 [==============================] - 47s 2s/step - loss: 0.7456 - accuracy: 0.7273 - val_loss: 0.8452 - val_accuracy: 0.7000
# Epoch 91/100
# 30/30 [==============================] - 46s 2s/step - loss: 0.7343 - accuracy: 0.7173 - val_loss: 0.8380 - val_accuracy: 0.6900
# Epoch 92/100
# 30/30 [==============================] - 44s 1s/step - loss: 0.7402 - accuracy: 0.7228 - val_loss: 0.8704 - val_accuracy: 0.6500
# Epoch 93/100
# 30/30 [==============================] - 46s 2s/step - loss: 0.6979 - accuracy: 0.7310 - val_loss: 0.7979 - val_accuracy: 0.7200
# Epoch 94/100
# 30/30 [==============================] - 44s 1s/step - loss: 0.7619 - accuracy: 0.7060 - val_loss: 0.8377 - val_accuracy: 0.7000
# Epoch 95/100
# 30/30 [==============================] - 46s 2s/step - loss: 0.7385 - accuracy: 0.7226 - val_loss: 0.8445 - val_accuracy: 0.6500
# Epoch 96/100
# 30/30 [==============================] - 45s 2s/step - loss: 0.7269 - accuracy: 0.7093 - val_loss: 0.8818 - val_accuracy: 0.6800
# Epoch 97/100
# 30/30 [==============================] - 47s 2s/step - loss: 0.7471 - accuracy: 0.7042 - val_loss: 0.8293 - val_accuracy: 0.7300
# Epoch 98/100
# 30/30 [==============================] - 46s 2s/step - loss: 0.7272 - accuracy: 0.7241 - val_loss: 0.8795 - val_accuracy: 0.6800
# Epoch 99/100
# 30/30 [==============================] - 45s 1s/step - loss: 0.6551 - accuracy: 0.7336 - val_loss: 0.9063 - val_accuracy: 0.6300
# Epoch 100/100
# 30/30 [==============================] - 46s 2s/step - loss: 0.7125 - accuracy: 0.7103 - val_loss: 0.8043 - val_accuracy: 0.6700

# %%
model.evaluate(test_data,test_labels)
# Out:
# 41/41 [==============================] - 16s 389ms/step - loss: 0.8324 - accuracy: 0.6964
# [0.8323615193367004, 0.6964149475097656]

# %%
x = result.history.keys()
x
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# Visualize training history
from keras.models import Sequential
from keras.layers import Dense
import matplotlib.pyplot as plt
import numpy
plt.plot(result.history['accuracy'])
plt.plot(result.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
y_pred1 = model.predict(test_data)
y_pred1.shape
np.argmax(y_pred1, axis=1)[0:30]
# Out:
# array([3, 1, 1, 4, 2, 0, 1, 4, 4, 2, 4, 3, 4, 3, 2, 2, 1, 1, 3, 0, 4, 0,
#        2, 1, 3, 0, 3, 0, 1, 4])

# %%
np.array(test_labels[0:30]).astype('int32')
# Out:
# array([3, 2, 2, 4, 0, 1, 1, 4, 4, 2, 4, 3, 4, 4, 2, 2, 1, 0, 3, 0, 4, 0,
#        1, 4, 3, 1, 3, 4, 1, 4], dtype=int32)
